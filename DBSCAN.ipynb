# %% [markdown]
# # Density Based Spatial Clustering Applications with Noise (DBSCAN)
#
# > The unsupervised learning method **DBSCAN** is preferred over kmeans when data is real, non-spherical and has noise, as clusters predicted with kmeans are severely affected in the presence of noise or outlier.
#
# > Also, the elbow criterion to select the optimal number of clusters k does not work. Read this paper for details: https://arxiv.org/pdf/2212.12189

# %% [markdown]
# >> DBSCAN demo from sklearn: https://scikit-learn.org/stable/auto_examples/cluster/plot_dbscan.html
#
#
# > The hyperparameters are epsilon distance (eps) and min. number of samples which is the minimum number of neighbors within the eps radial dist..

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import math
import missingno as msn

from sklearn import metrics
from sklearn.datasets import make_circles
from sklearn.preprocessing import StandardScaler, LabelEncoder, MinMaxScaler
from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors
#from sklearn.decomposition import PCA

# %%
df = pd.read_csv('train_data.csv')
df.info()

#pd.plotting.scatter_matrix(df, alpha = 0.45, figsize = (16, 12), diagonal = 'kde')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               10000 non-null  int64
#  1   profession       9507 non-null   object
#  2   age              5822 non-null   float64
#  3   gender           7421 non-null   object
#  4   highestDegree    10000 non-null  object
#  5   maritalStatus    10000 non-null  object
#  6   noOfKids         5467 non-null   float64
#  7   creditRisk       10000 non-null  float64
#  8   otherMembership  8553 non-null   object
#  9   pastStays1y      9050 non-null   float64
#  10  blogger          10000 non-null  object
#  11  articles         10000 non-null  int64
#  12  amexCard         10000 non-null  object
#  13  purposeTravel    10000 non-null  object
#  14  staySpend        10000 non-null  float64
#  15  loyaltyClass     10000 non-null  object
# dtypes: float64(5), int64(2), object(9)
# memory usage: 1.2+ MB

# %% [markdown]
# # Data exploration

# %%
df.head(5)
# Out:
#    ID      profession   age  gender           highestDegree maritalStatus  \
# 0   0   Public Sector   NaN    Male  High School Equivalent        Single
# 1   1  Private Sector   NaN     NaN        Associate Degree       Married
# 2   2        Business  44.0  Female          Masters Degree       Married
# 3   3   Public Sector   NaN    Male        Bachelors Degree        Single
# 4   4        Business   NaN  Female        Bachelors Degree       Widowed
#
#    noOfKids  creditRisk otherMembership  pastStays1y blogger  articles  \
# 0       0.0        3.18             IHG         23.0      No         7
# 1       1.0        2.07             IHG         48.0      No         4
# 2       NaN        2.81       Discovery         32.0      No         1
# 3       0.0        3.46             IHG          6.0      No        16
# 4       NaN        3.21        Marriott          NaN     Yes         0
#
#   amexCard    purposeTravel    staySpend loyaltyClass
# 0      Yes  Medical Tourism  1433.147527       Bronze
# 1      Yes   Leisure Travel    38.379023       Silver
# 2       No   Leisure Travel     0.000000       Bronze
# 3      Yes  Medical Tourism     0.000000       Bronze
# 4       No         Business   764.418767       Silver

# %%
fig = px.violin(df, x = 'gender', y = "creditRisk", color = "loyaltyClass", box = True, points = 'all')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5ca9fc1a-3e9e-4f15-ac77-e6ba3d122762" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ca9fc1a-3e9e-4f15-ac77-e6ba3d122762")) {                    Plotly.newPlot(                        "5ca9fc1a-3e9e-4f15-ac77-e6ba3d122762",                        [{"alignmentgroup":"True","box":{"visible":true},"hovertemplate":"loyaltyClass=Bronze\u003cbr\u003egender=%{x}\u003cbr\u003ecreditRisk=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bronze","marker":{"color":"#636efa"},"name":"Bronze","offsetgroup":"Bronze","orientation":"v","points":"all","scalegroup":"True","showlegend":true,"x":["Male","Female","Male",null,null,"Female","Male","Female","Female",null,null,null,"Female","Female",null,"Female","Female","Female","Female",null,"Female","Female",null,"Male","Male","Male",null,null,"Female","Female","Male","Female","Female","Female","Male","Female","Female","Female","Female","Male","Female","Female",null,"Female","Female","Male",null,"Female",null,"Female","Female",null,"Female","Female","Male","Female","Male","Female","Female","Female","Male","Male","Male",null,"Male","Female","Female","Female",null,"Female",null,"Female",null,"Male","Male","Female","Female",null,null,"Female",null,"Female","Female",null,"Male","Male","Female","Male","Female","Male","Female",null,"Female",null,"Female",null,"Female","Male",null,"Male","Female","Female","Male","Female",null,"Male",null,"Female","Female","Male","Female","Male","Male","Female","Female","Male","Female","Female","Female","Male","Female","Female",null,"Male","Male",null,"Female","Male","Male",null,null,null,null,null,"Female","Female","Male",null,"Male","Female","Male","Male","Female",null,"Female","Male","Female","Female","Female","Female","Female","Female",null,"Male",null,"Male",null,"Female","Female","Female",null,null,"Male","Female","Male","Female",null,null,"Male","Male",null,"Male","Male","Female",null,"Female","Female",null,"Female",null,"Female","Female","Female","Female","Female",null,null,"Female","Male","Female","Male","Male","Female","Male","Female","Female","Male","Male","Female",null,"Female","Female","Female","Male","Female","Male","Female","Male","Female","Female","Male",null,null,"Male","Male",null,"Male","Female","Female",null,"Female","Female",null,"Female","Male","Female",null,null,null,"Female",null,"Female","Male","Male","Female","Male","Female",null,"Female","Female","Female","Female","Female","Male",null,"Male",null,"Male","Female","Male",null,null,"Male",null,"Male","Female","Male","Male",null,"Female","Male","Female",null,"Female","Female","Female","Female","Female",null,"Male",null,"Female","Male","Male","Female","Female",null,null,"Male",null,null,"Male",null,"Female","Male","Female","Female","Female","Male","Female","Male",null,"Male","Female","Female","Female","Male","Female",null,null,null,null,"Female","Male","Female","Female",null,"Male",null,"Female","Female",null,"Female","Female","Female","Female",null,null,null,null,null,null,"Female","Male","Male","Male",null,"Female","Female","Female",null,"Male","Female","Female",null,null,null,"Female","Male","Female","Female","Female","Female",null,"Female","Female","Female","Female","Female",null,"Female","Male","Female","Male","Female",null,null,"Female","Male","Female","Female","Male","Male","Female","Female","Male","Male","Male","Male","Male","Female","Female",null,"Male","Male","Male",null,null,"Male",null,"Female","Female",null,"Male","Female","Male","Male",null,null,null,"Female",null,"Female","Female","Female","Female","Male","Female","Female",null,"Female","Male","Male",null,"Female",null,"Female","Male","Female","Female","Female",null,"Female",null,"Female","Female","Male","Female"," ...

# %%
fig = px.violin(df, x = 'loyaltyClass', y = "creditRisk", color = "gender", box = True, violinmode = 'overlay')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="668aa2d7-d406-468a-9100-981ab0d7643f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("668aa2d7-d406-468a-9100-981ab0d7643f")) {                    Plotly.newPlot(                        "668aa2d7-d406-468a-9100-981ab0d7643f",                        [{"alignmentgroup":"True","box":{"visible":true},"hovertemplate":"gender=Male\u003cbr\u003eloyaltyClass=%{x}\u003cbr\u003ecreditRisk=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Male","marker":{"color":"#636efa"},"name":"Male","offsetgroup":"Male","orientation":"v","scalegroup":"True","showlegend":true,"x":["Bronze","Bronze","Silver","Bronze","Gold","Silver","Silver","Silver","Silver","Silver","Silver","Silver","Silver","Silver","Bronze","Bronze","Silver","Silver","Bronze","Silver","Bronze","Silver","Bronze","Silver","Bronze","Silver","Silver","Silver","Bronze","Silver","Silver","Silver","Gold","Bronze","Silver","Bronze","Silver","Silver","Silver","Silver","Bronze","Silver","Silver","Silver","Bronze","Silver","Bronze","Bronze","Silver","Silver","Silver","Bronze","Silver","Bronze","Silver","Silver","Silver","Silver","Silver","Bronze","Bronze","Silver","Silver","Bronze","Bronze","Silver","Silver","Silver","Silver","Silver","Gold","Silver","Bronze","Bronze","Silver","Bronze","Silver","Silver","Silver","Silver","Bronze","Silver","Silver","Bronze","Silver","Bronze","Silver","Bronze","Silver","Bronze","Silver","Silver","Bronze","Bronze","Bronze","Silver","Bronze","Bronze","Silver","Silver","Silver","Silver","Silver","Silver","Silver","Bronze","Silver","Bronze","Bronze","Bronze","Silver","Silver","Silver","Silver","Bronze","Gold","Silver","Bronze","Bronze","Silver","Silver","Silver","Silver","Bronze","Bronze","Bronze","Bronze","Silver","Bronze","Bronze","Silver","Silver","Silver","Silver","Silver","Bronze","Bronze","Bronze","Silver","Silver","Bronze","Bronze","Bronze","Silver","Silver","Bronze","Bronze","Bronze","Silver","Bronze","Bronze","Bronze","Silver","Silver","Silver","Bronze","Silver","Silver","Silver","Silver","Silver","Silver","Silver","Bronze","Silver","Silver","Silver","Silver","Bronze","Bronze","Bronze","Silver","Bronze","Silver","Silver","Bronze","Silver","Bronze","Bronze","Silver","Bronze","Silver","Bronze","Silver","Silver","Silver","Bronze","Bronze","Silver","Bronze","Silver","Bronze","Silver","Bronze","Bronze","Gold","Silver","Bronze","Silver","Silver","Bronze","Silver","Bronze","Silver","Bronze","Silver","Bronze","Silver","Bronze","Silver","Gold","Silver","Bronze","Bronze","Silver","Bronze","Silver","Silver","Silver","Silver","Bronze","Bronze","Bronze","Silver","Silver","Silver","Silver","Silver","Bronze","Silver","Bronze","Gold","Silver","Silver","Silver","Silver","Silver","Silver","Silver","Bronze","Silver","Silver","Silver","Bronze","Silver","Silver","Bronze","Silver","Bronze","Bronze","Bronze","Bronze","Bronze","Bronze","Silver","Bronze","Silver","Silver","Bronze","Silver","Silver","Bronze","Bronze","Bronze","Silver","Bronze","Bronze","Bronze","Silver","Silver","Silver","Silver","Bronze","Bronze","Silver","Gold","Bronze","Silver","Bronze","Gold","Silver","Silver","Gold","Silver","Silver","Silver","Silver","Silver","Silver","Silver","Silver","Bronze","Silver","Silver","Silver","Bronze","Silver","Silver","Bronze","Silver","Silver","Bronze","Bronze","Silver","Silver","Bronze","Silver","Silver","Silver","Silver","Bronze","Bronze","Silver","Silver","Bronze","Bronze","Bronze","Bronze","Bronze","Bronze","Silver","Silver","Silver","Bronze","Bronze","Bronze","Bronze","Bronze","Bronze","Silver","Silver","Bronze","Bronze","Silver","Bronze","Bronze","Silver","Silver","Silver","Silver","Gold","Silver","Silver","Silver","Silver","Silver","Silver","Silver","S ...

# %% [markdown]
# # Clustering of customers

# %%
df1 = df[['creditRisk', 'staySpend']]

df1 = df1.dropna(how = 'any', axis = 0)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   creditRisk  10000 non-null  float64
#  1   staySpend   10000 non-null  float64
# dtypes: float64(2)
# memory usage: 156.4 KB

# %%
model = DBSCAN(eps = 1.0, min_samples = 300)                           #default parameters:eps = 0.5, min_samples = 5, metric = 'euclidean'
pred1 = model.fit(df1)

# %%
labels1 = pred1.labels_

# Number of clusters in labels, ignoring noise if present
n_clusters_ = len(set(labels1)) - (1 if -1 in labels1 else 0)
n_noise_ = list(labels1).count(-1)

print("Estimated number of clusters: %d" % n_clusters_)
print("Estimated number of noise points: %d" % n_noise_)
# Out:
# Estimated number of clusters: 1
# Estimated number of noise points: 4692

# %%
labels_true = df['loyaltyClass']

print(f"Homogeneity: {metrics.homogeneity_score(labels_true, labels1):.4f}")
print(f"Completeness: {metrics.completeness_score(labels_true, labels1):.4f}")
print(f"V-measure: {metrics.v_measure_score(labels_true, labels1):.4f}")
print(f"Adjusted Rand Index: {metrics.adjusted_rand_score(labels_true, labels1):.4f}")
print(
    "Adjusted Mutual Information:"
    f" {metrics.adjusted_mutual_info_score(labels_true, labels1):.4f}"
)
print(f"Silhouette Coefficient/Compactness: {metrics.silhouette_score(df1, labels1):.4f}")
# Out:
# Homogeneity: 0.0017
# Completeness: 0.0020
# V-measure: 0.0019
# Adjusted Rand Index: 0.0016
# Adjusted Mutual Information: 0.0017
# Silhouette Coefficient/Compactness: 0.2733
